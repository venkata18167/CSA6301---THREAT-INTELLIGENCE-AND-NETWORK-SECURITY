# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6301---THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/33_VPN_Tunnel_Encryption_Demonstration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 def xor_cipher(data: bytes, key: bytes) -> bytes:
    """
    Simple XOR stream cipher using a repeating key.
    (For educational purposes only.)
    """
    return bytes(
        b ^ key[i % len(key)]
        for i, b in enumerate(data)
    )
 def encrypt_tunnel(plaintext: str, key: str) -> bytes:
    """
    Encrypt plaintext using XOR cipher.
    """
    return xor_cipher(plaintext.encode(), key.encode())
 def decrypt_tunnel(ciphertext: bytes, key: str) -> str:
    """
    Decrypt ciphertext using XOR cipher.
    """
    return xor_cipher(ciphertext, key.encode()).decode(errors="replace")
 def test_experiment5():

    key = "VPN-Shared-Secret-Key"

    plaintext = "Transfer $50,000 to account 998211 - confidential"
    ciphertext = encrypt_tunnel(plaintext, key)

    print("Original Plaintext:")
    print(plaintext)

    print("\nEncrypted Ciphertext (bytes):")
    print(ciphertext)
    assert ciphertext != plaintext.encode()

    assert b"Transfer" not in ciphertext, \
        "Sensitive plaintext must not be visible."

    recovered = decrypt_tunnel(ciphertext, key)
    print("\nRecovered Plaintext:")
    print(recovered)
    assert recovered == plaintext
    wrong_recovered = decrypt_tunnel(ciphertext, "Wrong-Key")
    print("\nDecryption with Wrong Key:")
    print(wrong_recovered)
    assert wrong_recovered != plaintext
    print("\nAll test cases passed.")
test_experiment5()
# Out:
# Original Plaintext:
# Transfer $50,000 to account 998211 - confidential
#
# Encrypted Ciphertext (bytes):
# b'\x02"/C \x0e\x04\x00E@\x18cISBUTY$E\x1853!X=\x1cAK\\\\\x1fbTC_E\x17B%\x03\x1025 Y:\t\r'
#
# Recovered Plaintext:
# Transfer $50,000 to account 998211 - confidential
#
# Decryption with Wrong Key:
# UP@-G#Oe<j'4o1 s7w[TXe932xO&&e-Kd=yPYHfc
#
# All test cases passed.
