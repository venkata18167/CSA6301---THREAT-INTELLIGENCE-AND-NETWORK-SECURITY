# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6301---THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/11.exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from cryptography.fernet import Fernet

key = Fernet.generate_key()
cipher = Fernet(key)

message = "Hello! This is a secure VPN-like message."

print("Original Message:")
print(message)

encrypted_message = cipher.encrypt(message.encode())

print("\nEncrypted Message:")
print(encrypted_message)

decrypted_message = cipher.decrypt(encrypted_message).decode()

print("\nDecrypted Message:")
print(decrypted_message)
# Out:
# Original Message:
# Hello! This is a secure VPN-like message.
#
# Encrypted Message:
# b'gAAAAABqXy-xUC8HgGZqu5P2KaixLJce3wpBYEgdGw7V6k1_jbLGF9SRNhQ7DnVhd8YAOjTerV5CQrJ-ieLxAYkV2mGKAi7KAgmP7r_XZbVCuuZgWhcLZaLfqA9Y8e_wcByuaLDrO5TV'
#
# Decrypted Message:
# Hello! This is a secure VPN-like message.
